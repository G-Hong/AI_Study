# %% [markdown]
# #1. Neural Network Overview
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 변수 h는 z가 시그모이드 함수를 지난 후 각 뉴런의 출력값
#
# 인공신경망에 존재하는 모든 가중치 W에 대해서 역전파를 통해 업데이트 하는 것을 목표로 함.

# %% [markdown]
# #2. Forward Propagation
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #3. BackPropagation Step 1
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #2. BackPropagation Step 2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #5. 결과 확인
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://medium.com/@14prakash/back-propagation-is-very-simple-who-made-it-complicated-97b794c97e5c
#
# https://www.youtube.com/watch?v=ZMgax46Rd3g
